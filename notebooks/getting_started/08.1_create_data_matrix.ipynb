# %% [markdown]
# # Data matrix creation

# %% [markdown]
# ## Read individual files

# %%
import os
import pandas as pd

from pathlib import Path


sourceDirName = Path(os.environ['DATA_DIR'], 'sepsis_prediction', 'blood_pos_cohort_20250416', '00_source_files')
cleanedDirName = Path(os.environ['DATA_DIR'], 'sepsis_prediction', 'blood_pos_cohort_20250416', '03_cleaned_data')

vitals_column_names = ["person_id", "visit_occurrence_id", 'measurement_date', "Peripheral oxygen saturation", "Respiratory rate", "Temperature", "Systolic blood pressure", "Diastolic blood pressure", "Mean blood pressure", "Heart rate"]
labs_column_names = ["person_id", "visit_occurrence_id", 'measurement_date', "White blood cell count", "Basophil count", "Bicarbonate", "Blood urea", "Chloride salt", "Creatinine", "Eosinophil count", "Haemoglobin estimation", "Hematocrit", "Lymphocyte", "MCHC - Mean corpuscular haemoglobin concentration", "MCH - Mean corpuscular haemoglobin", "MCV - Mean corpuscular volume", "Monocyte", "Neutrophil count", "Potassium", "Red blood cell count", "Red blood cell distribution width", "Sodium", "Platelet", "Alanine aminotransferase", "GGT (gamma-glutamyl transferase) level", "Albumin", "Bilirubin", "Total alkaline phosphatase level", "Total protein measurement", "Globulin", "Calcium", "Phosphate measurement", "Magnesium measurement"]
vitals_avg =  pd.read_csv(cleanedDirName.as_posix() + '''/vitals_avg_episode_date.cleaned.csv''')[vitals_column_names]
vitals_min =  pd.read_csv(cleanedDirName.as_posix() + '''/vitals_min_episode_date.cleaned.csv''')[vitals_column_names]
vitals_max =  pd.read_csv(cleanedDirName.as_posix() + '''/vitals_max_episode_date.cleaned.csv''')[vitals_column_names]
vitals_first =  pd.read_csv(cleanedDirName.as_posix() + '''/vitals_first_episode_date.cleaned.csv''')[vitals_column_names]
vitals_last =  pd.read_csv(cleanedDirName.as_posix() + '''/vitals_last_episode_date.cleaned.csv''')[vitals_column_names]
labs_avg =  pd.read_csv(cleanedDirName.as_posix() + '''/labs_avg_episode_date.cleaned.csv''')[labs_column_names]
labs_min =  pd.read_csv(cleanedDirName.as_posix() + '''/labs_min_episode_date.cleaned.csv''')[labs_column_names]
labs_max =  pd.read_csv(cleanedDirName.as_posix() + '''/labs_max_episode_date.cleaned.csv''')[labs_column_names]
labs_first =  pd.read_csv(cleanedDirName.as_posix() + '''/labs_first_episode_date.cleaned.csv''')[labs_column_names]
labs_last =  pd.read_csv(cleanedDirName.as_posix() + '''/labs_last_episode_date.cleaned.csv''')[labs_column_names]

admissions = pd.read_csv(sourceDirName.as_posix() + '''/2024-04-03-admissions.csv''')

# %%
import os
import pandas as pd

from pathlib import Path


sourceDirName = Path(os.environ['DATA_DIR'], 'sepsis_prediction', 'blood_pos_cohort_20250416', '00_source_files')

icds =  pd.read_csv(sourceDirName.as_posix() + '''/2023-03-20-blood-pos-ICDs.csv''')
# Out:
# /tmp/ipykernel_12239/1401789047.py:9: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   icds =  pd.read_csv(sourceDirName.as_posix() + '''/2023-03-20-blood-pos-ICDs.csv''')

# %%
vitals_min.shape, vitals_max.shape, vitals_avg.shape, vitals_first.shape, vitals_last.shape
# Out:
# ((147979, 10), (147979, 10), (147979, 10), (147979, 10), (147979, 10))

# %%
labs_min.shape, labs_max.shape, labs_avg.shape, labs_first.shape, labs_last.shape
# Out:
# ((179439, 33), (179439, 33), (179439, 33), (179439, 33), (179439, 33))

# %%
admissions.shape
# Out:
# (216689, 15)

# %%
admissions["start_date"] = pd.to_datetime(admissions["start_date"]).dt.strftime('%Y-%m-%d')

# %%
admissions
# Out:
#         PATIENT_ID  EPISODE_ID  PARENT_EPISODE_ID  start_date  \
# 0          2141606        8800               8800  2013-08-31
# 1          2141606        8800               8800  2013-08-31
# 2          2141606        9467               9467  2013-09-03
# 3          2141606        9467               9467  2013-09-03
# 4          2141606        9871               9871  2013-09-05
# ...            ...         ...                ...         ...
# 216684      642636    18390389           18390389  2024-01-17
# 216685      642636    18406829           18406829  2024-02-27
# 216686      642636    18690618           18690618  2024-02-27
# 216687      642636    18696838           18696838  2024-02-28
# 216688      642636    18699844           18696838  2024-02-28
#
#                        end_date  \
# 0       2013-08-31 15:04:00.000
# 1       2013-08-31 15:04:00.000
# 2       2013-09-03 17:36:00.000
# 3       2013-09-03 17:36:00.000
# 4       2013-09-06 18:16:00.000
# ...                         ...
# 216684  2024-01-24 23:59:59.000
# 216685  2024-03-05 23:59:59.000
# 216686  2024-03-05 23:59:59.000
# 216687  2024-02-28 15:08:00.000
# 216688  2024-03-05 14:30:00.000
#
#                                   PRIMARY_VISIT_REASON   E_LOS   H_LOS  \
# 0                                             DIALYSIS    5.00    5.00
# 1                                             DIALYSIS    5.00    5.00
# 2                                             DIALYSIS    4.00    4.00
# 3                                             DIALYSIS    4.00    4.00
# 4       CONSTIPATION & BLOATING - PHX UMBILICAL HERNIA   31.00   31.00
# ...                                                ...     ...     ...
# 216684                                             NaN     NaN     NaN
# 216685                                  4 Month Review     NaN     NaN
# 216686                                             NaN     NaN     NaN
# 216687                                  Chest pain NEC    6.67    6.67
# 216688                                  Chest pain NEC  143.00  143.00
#
#            DATEOFDEATH_DATETIME         ADMIT_TYPE  \
# 0       2020-07-10 14:00:00.000  Planned Admission
# 1       2020-07-10 14:00:00.000  Planned Admission
# 2       2020-07-10 14:00:00.000  Planned Admission
# 3       2020-07-10 14:00:00.000  Planned Admission
# 4       2020-07-10 14:00:00.000  Admission from ED
# ...                         ...                ...
# 216684                      NaN                NaN
# 216685                      NaN                NaN
# 216686                      NaN                NaN
# 216687                      NaN                NaN
# 216688                      NaN  Admission from ED
#
#                                 ADMITTING_WARD  EPISODE_ORGANISM_IDENTIFIED  \
# 0       A-CGD - Alfred/Caulfield Haemodialysis                        85662
# 1       A-CGD - Alfred/Caulfield Haemodialysis                      9984732
# 2       A-CGD - Alfred/Caulfield Haemodialysis                        85662
# 3       A-CGD - Alfred/Caulfield Haemodialysis                      9984732
# 4               A-CC - Emergency Dept Cubicles                        85662
# ...                                        ...                          ...
# 216684                                     NaN                     18696838
# 216685                                     NaN                     18696838
# 216686                                     NaN                     18696838
# 216687                                     NaN                     18696838
# 216688             A-ICU - Intensive Care Unit                     18696838
#
#                             ORGANISM     Organism_FIRST_NOTED  \
# 0       Staphylococcus aureus (MRSA)  2014-08-31 08:45:41.000
# 1       Staphylococcus aureus (MRSA)  2014-08-31 08:17:49.000
# 2       Staphylococcus aureus (MRSA)  2014-08-31 08:45:41.000
# 3       Staphylococcus aureus (MRSA)  2014-08-31 08:17:49.000
# 4       Staphylococcus aureus (MRSA)  2014-08-31 08:45:41.000
# ...                              ...                      ...
# 216684  Burkholderia cepacia complex  2024-02-28 15:30:06.000
# 216685  Burkholderia cepacia complex  2024-02-28 15:30:06.000
# 216686  Burkholderia cepacia complex  2024-02-28 15:30:06.000
# 216687  Burkholderia cepacia complex  2024-02-28 15:30:06.000
# 216688  Burkholderia cepacia complex  2024-02-28 15:30:06.000
#
#             Organism_LAST_NOTED
# 0       2014-09-12 20:20:38.000
# 1       2014-08-31 08:17:49.000
# 2       2014-09-12 20:20:38.000
# 3       2014-08-31 08:17:49.000
# 4       2014-09-12 20:20:38.000
# ...                         ...
# 216684  2024-02-28 15:30:06.000
# 216685  2024-02-28 15:30:06.000
# 216686  2024-02-28 15:30:06.000
# 216687  2024-02-28 15:30:06.000
# 216688  2024-02-28 15:30:06.000
#
# [216689 rows x 15 columns]

# %%
icds.shape
# Out:
# (456648, 7)

# %%
def formatVitalsData(vitalsDf):

    vitalsDf['measurement_date'] = pd.to_datetime(vitalsDf["measurement_date"]).dt.strftime('%Y-%m-%d')
    vitalsDf = vitalsDf[vitals_column_names]
    return vitalsDf

# %%
def formatLabsData(labsDf):

    labsDf['measurement_date'] = pd.to_datetime(labsDf["measurement_date"]).dt.strftime('%Y-%m-%d')
    labsDf = labsDf[labs_column_names]
    return labsDf

# %%
vitals_avg = formatVitalsData(vitals_avg)
vitals_min = formatVitalsData(vitals_min)
vitals_max = formatVitalsData(vitals_max)
vitals_first = formatVitalsData(vitals_first)
vitals_last = formatVitalsData(vitals_last)

# %%
labs_avg = formatLabsData(labs_avg)
labs_min = formatLabsData(labs_min)
labs_max = formatLabsData(labs_max)
labs_first = formatLabsData(labs_first)
labs_last = formatLabsData(labs_last)

# %%
vitals_min.shape, vitals_max.shape, vitals_avg.shape, vitals_first.shape, vitals_last.shape
# Out:
# ((147979, 10), (147979, 10), (147979, 10), (147979, 10), (147979, 10))

# %%
labs_min.shape, labs_max.shape, labs_avg.shape, labs_first.shape, labs_last.shape
# Out:
# ((179439, 33), (179439, 33), (179439, 33), (179439, 33), (179439, 33))

# %%
vitals_avg
# Out:
#         person_id  visit_occurrence_id measurement_date  \
# 0         2096825                42323       2014-02-14
# 1         2141606                56954       2014-05-14
# 2         1951251                60383       2014-05-14
# 3         2083212                60747       2014-05-14
# 4         2102702                73384       2014-07-17
# ...           ...                  ...              ...
# 147974    2225152             18025236       2023-08-21
# 147975    2225152             18025236       2023-08-22
# 147976    2225152             18025236       2023-08-23
# 147977    2225152             18025236       2023-08-24
# 147978    2225152             18025236       2023-08-25
#
#         Peripheral oxygen saturation  Respiratory rate  Temperature  \
# 0                          97.943207         17.116405    36.522011
# 1                          97.943207         17.116405    36.522011
# 2                          97.943207         17.116405    36.522011
# 3                          97.943207         17.116405    36.522011
# 4                          97.943207         17.116405    36.522011
# ...                              ...               ...          ...
# 147974                     97.750000         17.750000    36.216667
# 147975                     97.200000         17.200000    36.060000
# 147976                     98.600000         17.200000    36.180000
# 147977                     97.166667         17.833333    36.400000
# 147978                     95.666667         18.666667    36.140000
#
#         Systolic blood pressure  Diastolic blood pressure  \
# 0                    112.428448                 65.072898
# 1                    112.428448                 65.072898
# 2                    112.428448                 65.072898
# 3                    112.428448                 65.072898
# 4                    112.428448                 65.072898
# ...                         ...                       ...
# 147974               141.111111                 76.111111
# 147975               130.400000                 73.800000
# 147976               129.400000                 67.400000
# 147977               126.500000                 65.833333
# 147978               109.714286                 66.571429
#
#         Mean blood pressure  Heart rate
# 0                 75.368105   78.270102
# 1                 75.368105   78.270102
# 2                 75.368105   78.270102
# 3                 75.368105   78.270102
# 4                 75.368105   78.270102
# ...                     ...         ...
# 147974            87.000000   79.625000
# 147975            85.000000   82.000000
# 147976            85.000000   85.000000
# 147977            76.600000   88.000000
# 147978            76.428571   80.500000
#
# [147979 rows x 10 columns]

# %%
labs_avg
# Out:
#         person_id  visit_occurrence_id measurement_date  \
# 0         2081899                12041       2013-09-16
# 1         2081899                12041       2013-09-17
# 2         2081899                12041       2013-09-18
# 3         2081899                12041       2013-09-19
# 4         2081899                12041       2013-09-20
# ...           ...                  ...              ...
# 179434    2225152             18025236       2023-08-20
# 179435    2225152             18025236       2023-08-21
# 179436    2225152             18025236       2023-08-22
# 179437    2225152             18025236       2023-08-24
# 179438    2225152             18025236       2023-08-25
#
#         White blood cell count  Basophil count  Bicarbonate  Blood urea  \
# 0                         3.90            0.04         24.0         5.1
# 1                         5.50            0.04         20.0         6.8
# 2                         4.60            0.05         17.0         9.3
# 3                         5.00            0.02         17.0         9.8
# 4                         4.90            0.03         19.0         9.6
# ...                        ...             ...          ...         ...
# 179434                    6.18            0.01         25.0         4.1
# 179435                    4.90            0.00         23.0         3.4
# 179436                    5.12            0.01         24.0         3.5
# 179437                    6.78            0.02         22.0         5.7
# 179438                    5.99            0.01         22.0         6.4
#
#         Chloride salt  Creatinine  Eosinophil count  ...  \
# 0          104.000000        97.0              0.04  ...
# 1          102.666667       130.0              0.00  ...
# 2          107.833333       161.0              0.03  ...
# 3          108.666667       127.0              0.04  ...
# 4          103.000000       123.0              0.07  ...
# ...               ...         ...               ...  ...
# 179434     113.000000        43.0              0.28  ...
# 179435     115.000000        41.0              0.18  ...
# 179436     116.000000        47.0              0.11  ...
# 179437     114.000000        55.0              0.16  ...
# 179438     113.000000        53.0              0.09  ...
#
#         Alanine aminotransferase  GGT (gamma-glutamyl transferase) level  \
# 0                           31.0                                   111.0
# 1                           31.0                                   118.0
# 2                           36.0                                    96.0
# 3                           33.0                                    86.0
# 4                           27.0                                    97.0
# ...                          ...                                     ...
# 179434                      18.0                                    15.0
# 179435                      18.0                                    14.0
# 179436                      16.0                                    14.0
# 179437                      15.0                                    13.0
# 179438                      12.0                                    14.0
#
#         Albumin  Bilirubin  Total alkaline phosphatase level  \
# 0          32.0        7.0                             100.0
# 1          28.0       15.0                              96.0
# 2          23.0        8.0                              78.0
# 3          24.0        6.0                              68.0
# 4          20.0        9.0                              76.0
# ...         ...        ...                               ...
# 179434     20.0        7.0                             100.0
# 179435     20.0        8.0                              95.0
# 179436     22.0        7.0                             104.0
# 179437     20.0        8.0                             104.0
# 179438     21.0        8.0                              97.0
#
#         Total protein measurement   Globulin   Calcium  Phosphate measurement  \
# 0                            69.0  37.106667  2.273467                 1.1009
# 1                            65.0  37.060000  2.080000                 0.7000
# 2                            59.0  35.945000  1.970000                 0.6600
# 3                            62.0  37.515000  2.090000                 0.8600
# 4                            62.0  39.475000  2.160000                 0.7700
# ...                           ...        ...       ...                    ...
# 179434                       46.0  26.000000  1.850000                 0.8700
# 179435                       46.0  26.000000  1.830000                 0.8000
# 179436                       47.0  25.000000  1.940000                 0.8200
# 179437                       45.0  25.000000  1.980000                 0.8000
# 179438                       45.0  24.000000  2.040000                 0.7500
#
#         Magnesium measurement
# 0                    0.769667
# 1                    0.680000
# 2                    0.810000
# 3                    0.970000
# 4                    0.900000
# ...                       ...
# 179434               0.650000
# 179435               0.610000
# 179436               0.630000
# 179437               0.650000
# 179438               1.100000
#
# [179439 rows x 33 columns]

# %% [markdown]
# ## Create target variable (Incidence of sepsis)

# %%
sepsisDf = icds[(icds.AUSTRALIAN_MODIFICATION.str.startswith('A40')) | (icds.AUSTRALIAN_MODIFICATION.str.startswith('A41'))][['EPISODE_ID', 'PATIENT_ID']].drop_duplicates()
sepsisDf['sepsis'] = 1
sepsisDf
# Out:
#         EPISODE_ID  PATIENT_ID  sepsis
# 221       17030802     2188789       1
# 336       17003144     1466886       1
# 439       16982177     2097130       1
# 1124      16875811     2090730       1
# 1241      16859246     2193278       1
# ...            ...         ...     ...
# 454745       10444     2135518       1
# 454885        9543     2143511       1
# 455084        8251     2100912       1
# 456046        3055      542353       1
# 456088        2967     2144093       1
#
# [3983 rows x 3 columns]

# %%
admissions[['PATIENT_ID', 'EPISODE_ID', 'start_date']].drop_duplicates()
# Out:
#         PATIENT_ID  EPISODE_ID  start_date
# 0          2141606        8800  2013-08-31
# 2          2141606        9467  2013-09-03
# 4          2141606        9871  2013-09-05
# 6          2141606       10349  2013-09-07
# 8          2141606       10798  2013-09-10
# ...            ...         ...         ...
# 216684      642636    18390389  2024-01-17
# 216685      642636    18406829  2024-02-27
# 216686      642636    18690618  2024-02-27
# 216687      642636    18696838  2024-02-28
# 216688      642636    18699844  2024-02-28
#
# [123845 rows x 3 columns]

# %% [markdown]
# ## Merge all the files

# %%
import pandas as pd


mergedDf = pd.concat([vitals_avg, vitals_min, vitals_max, vitals_first, vitals_last, labs_avg, labs_min, labs_max, labs_first, labs_last], ignore_index=True)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = mergedDf[['person_id', 'visit_occurrence_id', 'measurement_date']]
mergedDf = pd.merge(mergedDf, admissions[['PATIENT_ID', 'EPISODE_ID', 'start_date']].drop_duplicates(), how='inner', left_on=['person_id', 'visit_occurrence_id'], right_on=['PATIENT_ID', 'EPISODE_ID'])
mergedDf = mergedDf.drop(['PATIENT_ID', 'EPISODE_ID'], axis = 1)
mergedDf = pd.merge(mergedDf, sepsisDf, how='left', left_on=['person_id', 'visit_occurrence_id'], right_on=['PATIENT_ID', 'EPISODE_ID'])
mergedDf = mergedDf.drop(['PATIENT_ID', 'EPISODE_ID'], axis = 1)
mergedDf['sepsis'].fillna(0, inplace=True)
mergedDf['sepsis'] = mergedDf['sepsis'].astype(int)
mergedDf = pd.merge(mergedDf, vitals_avg.add_suffix('_avg').add_prefix('vitals_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['vitals_person_id_avg', 'vitals_visit_occurrence_id_avg', 'vitals_measurement_date_avg'])
mergedDf = mergedDf.drop(['vitals_person_id_avg', 'vitals_visit_occurrence_id_avg', 'vitals_measurement_date_avg'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, vitals_min.add_suffix('_min').add_prefix('vitals_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['vitals_person_id_min', 'vitals_visit_occurrence_id_min', 'vitals_measurement_date_min'])
mergedDf = mergedDf.drop(['vitals_person_id_min', 'vitals_visit_occurrence_id_min', 'vitals_measurement_date_min'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, vitals_max.add_suffix('_max').add_prefix('vitals_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['vitals_person_id_max', 'vitals_visit_occurrence_id_max', 'vitals_measurement_date_max'])
mergedDf = mergedDf.drop(['vitals_person_id_max', 'vitals_visit_occurrence_id_max', 'vitals_measurement_date_max'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, vitals_first.add_suffix('_first').add_prefix('vitals_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['vitals_person_id_first', 'vitals_visit_occurrence_id_first', 'vitals_measurement_date_first'])
mergedDf = mergedDf.drop(['vitals_person_id_first', 'vitals_visit_occurrence_id_first', 'vitals_measurement_date_first'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, vitals_last.add_suffix('_last').add_prefix('vitals_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['vitals_person_id_last', 'vitals_visit_occurrence_id_last', 'vitals_measurement_date_last'])
mergedDf = mergedDf.drop(['vitals_person_id_last', 'vitals_visit_occurrence_id_last', 'vitals_measurement_date_last'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, labs_avg.add_suffix('_avg').add_prefix('labs_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['labs_person_id_avg', 'labs_visit_occurrence_id_avg', 'labs_measurement_date_avg'])
mergedDf = mergedDf.drop(['labs_person_id_avg', 'labs_visit_occurrence_id_avg', 'labs_measurement_date_avg'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, labs_min.add_suffix('_min').add_prefix('labs_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['labs_person_id_min', 'labs_visit_occurrence_id_min', 'labs_measurement_date_min'])
mergedDf = mergedDf.drop(['labs_person_id_min', 'labs_visit_occurrence_id_min', 'labs_measurement_date_min'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, labs_max.add_suffix('_max').add_prefix('labs_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['labs_person_id_max', 'labs_visit_occurrence_id_max', 'labs_measurement_date_max'])
mergedDf = mergedDf.drop(['labs_person_id_max', 'labs_visit_occurrence_id_max', 'labs_measurement_date_max'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, labs_max.add_suffix('_first').add_prefix('labs_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['labs_person_id_first', 'labs_visit_occurrence_id_first', 'labs_measurement_date_first'])
mergedDf = mergedDf.drop(['labs_person_id_first', 'labs_visit_occurrence_id_first', 'labs_measurement_date_first'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = pd.merge(mergedDf, labs_max.add_suffix('_last').add_prefix('labs_'), how='left', left_on=['person_id', 'visit_occurrence_id', 'measurement_date'], right_on=['labs_person_id_last', 'labs_visit_occurrence_id_last', 'labs_measurement_date_last'])
mergedDf = mergedDf.drop(['labs_person_id_last', 'labs_visit_occurrence_id_last', 'labs_measurement_date_last'], axis = 1)
mergedDf = mergedDf.drop_duplicates(subset=['person_id', 'visit_occurrence_id', 'measurement_date'])
mergedDf = mergedDf.dropna()
mergedDf
# Out:
# /tmp/ipykernel_12239/2386270462.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   mergedDf['sepsis'].fillna(0, inplace=True)
#         person_id  visit_occurrence_id measurement_date  start_date  sepsis  \
# 0         2096825                42323       2014-02-14  2014-02-12       0
# 1         2141606                56954       2014-05-14  2014-04-22       0
# 2         1951251                60383       2014-05-14  2014-05-08       1
# 5         2141606                82780       2014-08-21  2014-08-18       0
# 7         2141606                85662       2014-09-23  2014-08-30       1
# ...           ...                  ...              ...         ...     ...
# 147689    2225152             18025236       2023-08-20  2023-08-14       0
# 147690    2225152             18025236       2023-08-21  2023-08-14       0
# 147691    2225152             18025236       2023-08-22  2023-08-14       0
# 147693    2225152             18025236       2023-08-24  2023-08-14       0
# 147694    2225152             18025236       2023-08-25  2023-08-14       0
#
#         vitals_Peripheral oxygen saturation_avg  vitals_Respiratory rate_avg  \
# 0                                     97.943207                    17.116405
# 1                                     97.943207                    17.116405
# 2                                     97.943207                    17.116405
# 5                                     97.943207                    17.116405
# 7                                     97.943207                    17.116405
# ...                                         ...                          ...
# 147689                                97.666667                    16.833333
# 147690                                97.750000                    17.750000
# 147691                                97.200000                    17.200000
# 147693                                97.166667                    17.833333
# 147694                                95.666667                    18.666667
#
#         vitals_Temperature_avg  vitals_Systolic blood pressure_avg  \
# 0                    36.522011                          112.428448
# 1                    36.522011                          112.428448
# 2                    36.522011                          112.428448
# 5                    36.522011                          112.428448
# 7                    36.522011                          112.428448
# ...                        ...                                 ...
# 147689               36.316667                          128.285714
# 147690               36.216667                          141.111111
# 147691               36.060000                          130.400000
# 147693               36.400000                          126.500000
# 147694               36.140000                          109.714286
#
#         vitals_Diastolic blood pressure_avg  ...  \
# 0                                 65.072898  ...
# 1                                 65.072898  ...
# 2                                 65.072898  ...
# 5                                 65.072898  ...
# 7                                 65.072898  ...
# ...                                     ...  ...
# 147689                            66.857143  ...
# 147690                            76.111111  ...
# 147691                            73.800000  ...
# 147693                            65.833333  ...
# 147694                            66.571429  ...
#
#         labs_Alanine aminotransferase_last  \
# 0                                    31.91
# 1                                     5.00
# 2                                    17.00
# 5                                    29.00
# 7                                     7.00
# ...                                    ...
# 147689                               18.00
# 147690                               18.00
# 147691                               16.00
# 147693                               15.00
# 147694                               12.00
#
#         labs_GGT (gamma-glutamyl transferase) level_last  labs_Albumin_last  \
# 0                                                 133.54              27.79
# 1                                                  20.00              21.00
# 2                                                 216.00              24.00
# 5                                                  45.00              32.00
# 7                                                  28.00              25.00
# ...                                                  ...                ...
# 147689                                             15.00              20.00
# 147690                                             14.00              20.00
# 147691                                             14.00              22.00
# 147693                                             13.00              20.00
# 147694                                             14.00              21.00
#
#         labs_Bilirubin_last  labs_Total alkaline phosphatase level_last  \
# 0                      7.84                                      145.08
# 1                      9.00                                       62.00
# 2                     17.00                                       94.00
# 5                      7.00                                      110.00
# 7                      8.00                                       87.00
# ...                     ...                                         ...
# 147689                 7.00                                      100.00
# 147690                 8.00                                       95.00
# 147691                 7.00                                      104.00
# 147693                 8.00                                      104.00
# 147694                 8.00                                       97.00
#
#         labs_Total protein measurement_last  labs_Globulin_last  \
# 0                                     66.55               39.66
# 1                                     60.00               36.94
# 2                                     62.00               37.40
# 5                                     79.00               47.00
# 7                                     75.00               50.00
# ...                                     ...                 ...
# 147689                                46.00               26.00
# 147690                                46.00               26.00
# 147691                                47.00               25.00
# 147693                                45.00               25.00
# 147694                                45.00               24.00
#
#         labs_Calcium_last  labs_Phosphate measurement_last  \
# 0                  2.3018                           1.2803
# 1                  2.1100                           2.0200
# 2                  2.0900                           0.8100
# 5                  2.4000                           1.8300
# 7                  2.3100                           1.4700
# ...                   ...                              ...
# 147689             1.8500                           0.8700
# 147690             1.8300                           0.8000
# 147691             1.9400                           0.8200
# 147693             1.9800                           0.8000
# 147694             2.0400                           0.7500
#
#         labs_Magnesium measurement_last
# 0                                0.8157
# 1                                0.9200
# 2                                0.6900
# 5                                0.9000
# 7                                1.0000
# ...                                 ...
# 147689                           0.6500
# 147690                           0.6100
# 147691                           0.6300
# 147693                           0.6500
# 147694                           1.1000
#
# [98434 rows x 190 columns]

# %%
len(mergedDf.visit_occurrence_id.unique()), len(mergedDf.person_id.unique())
# Out:
# (14698, 3923)

# %%
mergedDf.sepsis.value_counts()
# Out:
# sepsis
# 0    85462
# 1    12972
# Name: count, dtype: int64

# %%
mergedDf[['person_id', 'visit_occurrence_id', 'sepsis']].drop_duplicates().sepsis.value_counts()
# Out:
# sepsis
# 0    14109
# 1      589
# Name: count, dtype: int64

# %%
mergedDf[['person_id', 'visit_occurrence_id', 'sepsis']].drop_duplicates().sepsis.value_counts()/mergedDf[['person_id', 'visit_occurrence_id', 'sepsis']].drop_duplicates().shape[0]*100
# Out:
# sepsis
# 0    95.992652
# 1     4.007348
# Name: count, dtype: float64

# %% [markdown]
# ## Save merged data to a file

# %%
datamatrixDirName = Path(os.environ['DATA_DIR'], 'sepsis_prediction', 'blood_pos_cohort_20250416', '04_data_matrix')

datamatrixDirName.mkdir(exist_ok=True)

mergedDf.to_csv(Path(datamatrixDirName, 'data_matrix_traditional_ml.csv'), index=False)
