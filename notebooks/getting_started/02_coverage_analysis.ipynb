# %% [markdown]
# # Analysing the coverage of individual attributes

# %% [markdown]
# ## A function to establish the DB connection

# %%
import os

import psycopg2


def getConnection():
    # Connect to postgres with a copy of the MIMIC-III database
    con = psycopg2.connect(
        dbname='omop_migration_etl_20250416',
        user=os.environ['POSTGRES_USER_NAME'],
        host=os.environ['POSTGRES_HOSTNAME'],
        port=os.environ['POSTGRES_PORT_NUMBER'],
        password=os.environ['POSTGRES_PASSWORD']
        )
    return con

# %% [markdown]
# ## Coverage analysis for vitals

# %%
import pandas as pd


con = getConnection()

coverageQuery = '''
    select
        con.concept_name,
        con.concept_code,
        (count(distinct mmt.person_id)::float * 100)/(select count(distinct(person_id)) from omop_migration_etl_20250416.cdm_measurement) as person_level_coverage,
        (count(distinct mmt.visit_occurrence_id)::float * 100)/(select count(distinct(visit_occurrence_id)) from omop_migration_etl_20250416.cdm_measurement) as episode_level_coverage
    from
        omop_migration_etl_20250416.cdm_measurement mmt
    inner join omop_migration_etl_20250416.concept con
        on con.concept_code = mmt.measurement_concept_id
    where
        mmt.unit_id = 'chartevents'
    group by
        con.concept_name, con.concept_code
    order by
        episode_level_coverage desc
    ;
'''

coverageDf = pd.read_sql_query(coverageQuery, con)
coverageDf
# Out:
# /tmp/ipykernel_155964/3189846400.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   coverageDf = pd.read_sql_query(coverageQuery, con)
#                             concept_name concept_code  person_level_coverage  \
# 0                Systolic blood pressure    271649006              79.559387
# 1               Diastolic blood pressure    271650006              79.482759
# 2           Peripheral oxygen saturation    431314004              80.498084
# 3                            Temperature    246508008              78.927203
# 4                       Respiratory rate     86290005              78.850575
# 5                    Mean blood pressure      6797001              77.796935
# 6                             Heart rate    364075005              67.605364
# 7                       Peripheral pulse     54718008              78.237548
# 8                            Body weight     27113001              68.850575
# 9                                 Oxygen     24099007              58.888889
# 10                       Body mass index     60621009              56.264368
# 11         Inspired oxygen concentration    250774007              47.567050
# 12                      Oral temperature    415945006              31.858238
# 13   Invasive systolic arterial pressure    251071003              26.877395
# 14  Invasive diastolic arterial pressure    251073000              26.800766
# 15               Central venous pressure     71420008               8.754789
# 16             Urinary bladder structure     89837001               7.567050
# 17                         Intravascular    261101003               1.762452
# 18                 Intracranial pressure    250844005               1.168582
# 19           Cerebral perfusion pressure    250846007               1.091954
# 20                   Temperature of skin    364537001               0.287356
# 21                       Brain structure     12738006               0.191571
#
#     episode_level_coverage
# 0                46.205586
# 1                46.148807
# 2                45.738246
# 3                43.665786
# 4                43.602455
# 5                37.786901
# 6                36.070407
# 7                29.263392
# 8                24.109541
# 9                16.267389
# 10               14.367452
# 11                8.442707
# 12                5.811186
# 13                3.614247
# 14                3.603328
# 15                1.061344
# 16                0.875718
# 17                0.205281
# 18                0.133214
# 19                0.124479
# 20                0.032758
# 21                0.021838

# %% [markdown]
# ## Coverage analysis for labs

# %%
import pandas as pd


con = getConnection()

coverageQuery = '''
    select
        con.concept_name,
        con.concept_code,
        (count(distinct mmt.person_id)::float * 100)/(select count(distinct(person_id)) from omop_migration_etl_20250416.cdm_measurement) as person_level_coverage,
        (count(distinct mmt.visit_occurrence_id)::float * 100)/(select count(distinct(visit_occurrence_id)) from omop_migration_etl_20250416.cdm_measurement) as episode_level_coverage
    from
        omop_migration_etl_20250416.cdm_measurement mmt
    inner join omop_migration_etl_20250416.concept con
        on con.concept_code = mmt.measurement_concept_id
    where
        mmt.unit_id = 'labevents'
    group by
        con.concept_name, con.concept_code
    order by
        episode_level_coverage desc
    ;
'''

coverageDf = pd.read_sql_query(coverageQuery, con)
coverageDf
# Out:
# /tmp/ipykernel_155964/2210091202.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   coverageDf = pd.read_sql_query(coverageQuery, con)
#                                          concept_name      concept_code  \
# 0                              Haemoglobin estimation  1022431000000105
# 1                                    Eosinophil count          71960002
# 2                                            Monocyte          55918008
# 3                                          Lymphocyte          56972008
# 4                                Red blood cell count          14089001
# 5                                          Hematocrit         165418001
# 6   MCHC - Mean corpuscular haemoglobin concentration  1022481000000109
# 7                  MCH - Mean corpuscular haemoglobin  1022471000000107
# 8                       MCV - Mean corpuscular volume  1022491000000106
# 9                   Red blood cell distribution width   993501000000105
# 10                             White blood cell count            767002
# 11                                     Basophil count  1022571000000108
# 12                                   Neutrophil count          30630007
# 13                                           Platelet          16378004
# 14                                      Chloride salt          50213009
# 15                                             Sodium          39972003
# 16                                          Potassium          88480006
# 17                                         Creatinine          15373003
# 18                                         Blood urea  1028281000000106
# 19                                        Bicarbonate          68615006
# 20                                            Albumin          52454007
# 21                   Total alkaline phosphatase level   997611000000101
# 22             GGT (gamma-glutamyl transferase) level  1028091000000102
# 23                          Total protein measurement         304383000
# 24                           Alanine aminotransferase          56935002
# 25                                           Globulin          81905004
# 26                                          Bilirubin          79706000
# 27                                            Calcium           5540006
# 28                              Phosphate measurement         104866001
# 29                              Magnesium measurement          38151008
# 30  Estimated glomerular filtration rate by labora...  1107411000000104
# 31                   Corrected measurement of calcium         443796007
# 32                                   Prothrombin time   852471000000107
# 33  International normalized ratio derived warfari...         439814009
# 34                        Elevated C-reactive protein   119971000119104
# 35             Partial thromboplastin time, activated          42525009
# 36                             Fibrinogen measurement         250346004
# 37                                      Thrombin time  1015431000000108
# 38                            Glucose level - finding         365811003
# 39                                      Urine pH test         167305006
# 40                                        Erythrocyte          41898006
# 41                                          Leukocyte          52501007
# 42               Serum ionized calcium (pH 7.4) level  1013241000000102
# 43       Cord venous blood partial pressure of oxygen   791921000000101
# 44                         Calculus carbonate content  1024181000000106
# 45                  Hemoglobin saturation with oxygen         103228002
# 46                                            Glucose          67079006
# 47        Arterial partial pressure of carbon dioxide         144272005
# 48                                 Carbohydrate level  1032081000000104
# 49                                    Fluid sample pH  1024211000000107
# 50                                            Lactate          83036002
# 51                                        Base excess         129907001
#
#     person_level_coverage  episode_level_coverage
# 0               99.923372               79.568037
# 1               99.885057               78.642091
# 2               99.885057               78.609334
# 3               99.885057               78.602782
# 4               99.904215               78.423708
# 5               99.904215               78.423708
# 6               99.904215               78.421524
# 7               99.904215               78.421524
# 8               99.904215               78.417156
# 9               99.904215               78.366928
# 10              99.885057               78.358193
# 11              99.885057               78.227163
# 12              99.885057               78.183486
# 13              99.693487               78.120155
# 14              99.770115               77.593850
# 15              99.731801               77.554541
# 16              99.731801               76.964906
# 17              99.770115               76.866633
# 18              99.770115               76.591470
# 19              99.770115               76.549977
# 20              98.122605               69.692734
# 21              98.122605               69.511476
# 22              98.103448               69.498373
# 23              98.045977               69.245048
# 24              97.854406               69.155511
# 25              98.045977               68.987356
# 26              97.892720               68.225197
# 27              94.789272               64.514861
# 28              94.674330               63.947064
# 29              94.789272               63.905571
# 30              85.153257               54.220262
# 31              75.842912               47.033260
# 32              86.666667               37.692996
# 33              86.647510               37.682077
# 34              96.321839               35.886965
# 35              86.436782               35.871678
# 36              83.773946               33.288201
# 37              83.352490               31.082527
# 38              87.413793               25.795462
# 39              86.494253               22.984866
# 40              84.750958               21.820882
# 41              81.360153               20.735516
# 42              74.885057               16.763119
# 43              74.061303               16.295779
# 44              74.099617               16.249918
# 45              73.984674               16.249918
# 46              74.118774               16.247734
# 47              74.099617               16.241183
# 48              74.080460               16.236815
# 49              74.080460               16.236815
# 50              73.888889               16.040270
# 51              57.260536               10.626542
